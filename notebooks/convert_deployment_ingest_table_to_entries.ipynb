# %%
import pandas as pd

from pathlib import Path

# %%
input_file: Path = Path(
    "/home/martin/data/acfr_benthloc_ingest_telemetry/deployment_ingest_table.csv"
)
export_file: Path = Path(
    "/home/martin/data/acfr_benthloc_ingest_telemetry/deployment_ingest_entries.json"
)

df: pd.DataFrame = pd.read_csv(input_file)
df.to_json(export_file, orient="records", indent=2)
